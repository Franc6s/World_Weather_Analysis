# %%
# Create a practice set of random latitude and longitude combinations.

x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677,-61.13376282]

coordinates = zip(x,y)

# %%
#use the zip tuple function to display the latitude and longitude combination

for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
#Use the citipymodule to determine city based on latitutde and longitude.
from citipy import citipy
city = citipy.nearest_city(coordinate[0],coordinate[1])

# %%
city.city_name
# Out:
# 'saint george'

# %%
city.country_code
# Out:
# 'bm'

# %%
print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# saint george bm

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
api.openweathermap.org/data/2.5/weather?q={saint george}&appid={1e49566c725765ab6e4529a71229a2dc}
# Out:
#   File "<ipython-input-27-f3e88cf19843>", line 1
#     api.openweathermap.org/data/2.5/weather?q={saint george}&appid={1e49566c725765ab6e4529a71229a2dc}
#                                            ^
# SyntaxError: invalid syntax

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1e49566c725765ab6e4529a71229a2dc

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1e49566c725765ab6e4529a71229a2dc&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":67.64,"feels_like":67.59,"temp_min":62.94,"temp_max":70.63,"pressure":1012,"humidity":74},"visibility":10000,"wind":{"speed":4,"deg":350,"gust":11.01},"clouds":{"all":9},"dt":1626922138,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1626859566,"sunset":1626912891},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 67.64,
#   'feels_like': 67.59,
#   'temp_min': 62.94,
#   'temp_max': 70.63,
#   'pressure': 1012,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 350, 'gust': 11.01},
#  'clouds': {'all': 9},
#  'dt': 1626922138,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1626859566,
#   'sunset': 1626912891},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 67.64,
#   'feels_like': 67.59,
#   'temp_min': 62.94,
#   'temp_max': 70.63,
#   'pressure': 1012,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 350, 'gust': 11.01},
#  'clouds': {'all': 9},
#  'dt': 1626922138,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1626859566,
#   'sunset': 1626912891},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 70.63 74 9 4

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 7, 22, 2, 48, 58)
